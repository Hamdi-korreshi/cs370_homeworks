# %%
import numpy as np
three_dim = np.array([[4, 2, 1], [2,3,1.5], [1, 1.5, 2]])
mean2 = [0,0,0]
np.random.seed(42)
X = np.random.multivariate_normal(mean2, three_dim, size=200)

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/hamdi/.venv/lib/python3.10/site-packages (from seaborn) (1.26.2)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/hamdi/.venv/lib/python3.10/site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hamdi/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/hamdi/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hamdi/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hamdi/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/hamdi/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /home/hamdi/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/hamdi/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hamdi/.venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Collecting pytz>=2020.1 (from pandas>=1.2->seaborn)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.2->seaborn)
#   Downloading tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/hamdi/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 41.7 MB/s eta 0:00:0000:0100:01
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 19.2 MB/s eta 0:00:00
# Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas, seaborn
# Successfully installed pandas-2.2.0 pytz-2023.4 seaborn-0.13.2 tzdata-2023.4
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
print(pca.components_)
print(pca.explained_variance_)
print(pca.mean_.shape)
# Out:
# [[ 0.68262505  0.59843923  0.41939663]
#  [ 0.68888529 -0.33547005 -0.64257054]]
# [5.00340763 1.91548707]
# (3,)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 12
#      10 for length, vector in zip(pca.explained_variance_, pca.components_):
#      11     v = vector * 3 * np.sqrt(length)
# ---> 12     draw_vector(pca.mean_, pca.mean_ + v)
#      13 plt.axis('equal');
#
# Cell In[34], line 6, in draw_vector(v0, v1, ax, color)
#       2 ax = ax or plt.gca()
#       3 arrowprops=dict(arrowstyle='->',
#       4                 linewidth=200,
#       5                 shrinkA=0, shrinkB=0, color=color)
# ----> 6 ax.annotate('', v1, v0, arrowprops=arrowprops)
#
# File ~/.venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:711, in Axes.annotate(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#     706 @_docstring.dedent_interpd
#     707 def annotate(self, text, xy, xytext=None, xycoords='data', textcoords=None,
#     708              arrowprops=None, annotation_clip=None, **kwargs):
#     709     # Signature must match Annotation. This is verified in
#     710     # test_annotate_signature().
# --> 711     a = mtext.Annotation(text, xy, xytext=xytext, xycoords=xycoords,
#     712                          textcoords=textcoords, arrowprops=arrowprops,
#     713                          annotation_clip=annotation_clip, **kwargs)
#     714     a.set_transform(mtransforms.IdentityTransform())
#     715     if kwargs.get('clip_on', False) and a.get_clip_path() is None:
#
# File ~/.venv/lib/python3.10/site-packages/matplotlib/text.py:1805, in Annotation.__init__(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    1633 def __init__(self, text, xy,
#    1634              xytext=None,
#    1635              xycoords='data',
#    (...)
#    1638              annotation_clip=None,
#    1639              **kwargs):
#    1640     """
#    1641     Annotate the point *xy* with text *text*.
#    1642
#    (...)
#    1803
#    1804     """
# -> 1805     _AnnotationBase.__init__(self,
#    1806                              xy,
#    1807                              xycoords=xycoords,
#    1808                              annotation_clip=annotation_clip)
#    1809     # warn about wonky input data
#    1810     if (xytext is None and
#    1811             textcoords is not None and
#    1812             textcoords != xycoords):
#
# File ~/.venv/lib/python3.10/site-packages/matplotlib/text.py:1450, in _AnnotationBase.__init__(self, xy, xycoords, annotation_clip)
#    1445 def __init__(self,
#    1446              xy,
#    1447              xycoords='data',
#    1448              annotation_clip=None):
# -> 1450     x, y = xy  # Make copy when xy is an array (and check the shape).
#    1451     self.xy = x, y
#    1452     self.xycoords = xycoords
#
# ValueError: too many values to unpack (expected 2)
